# %%
import pandas as pd
import numpy as np
import calculations
import importlib

# %%
pd.options.display.max_columns = None
pd.options.display.float_format = "{:,.2f}".format

# %%
loan = pd.read_csv("./loan_book_df.csv",index_col=0)

# %%
loan
# Out:
#                       23-Sep       23-Oct       23-Nov       23-Dec  \
# Opening Balance    52,421.62   651,340.23 1,232,125.87 1,896,053.61
# New Disbursements 609,011.05   651,480.25   805,080.25   808,900.00
# Repayments        -11,375.86  -118,634.40  -236,002.32  -375,427.20
# Interest Income     1,283.41    47,939.79    94,849.82   145,784.24
# Closing Balance   651,340.23 1,232,125.87 1,896,053.61 2,475,310.66
#
#                         24-Jan       24-Feb       24-Mar        24-Apr  \
# Opening Balance   2,475,310.66 3,251,907.14 3,943,507.57  4,747,355.00
# New Disbursements 1,097,573.00 1,141,909.25 1,396,650.00  1,588,680.00
# Repayments         -505,667.68  -687,338.52  -876,023.89 -1,009,531.79
# Interest Income     184,691.17   237,029.70   283,221.31    336,260.71
# Closing Balance   3,251,907.14 3,943,507.57 4,747,355.00  5,662,763.92
#
#                          24-May        24-Jun        24-Jul        24-Aug  \
# ...

# %%
combined_loan = calculations.loan_per_year_calculations(loan)
combined_loan
# Out:
#                           2023           2024           2025           2026  \
# Opening Balance      52,421.62   2,475,310.66  12,082,545.54  15,558,247.17
# New Disbursements 2,874,471.55  21,264,812.25  24,420,000.00  24,420,000.00
# Repayments         -741,439.78 -17,647,762.63 -30,843,136.24 -31,117,279.81
# Interest Income     289,857.27   5,990,185.26   9,898,837.87   9,937,279.81
# Closing Balance   2,475,310.66  12,082,545.54  15,558,247.17  18,798,247.17
#
#                             2027           2028
# Opening Balance    18,798,247.17  22,038,247.17
# New Disbursements  24,420,000.00  16,280,000.00
# Repayments        -31,117,279.81 -20,744,853.21
# Interest Income     9,937,279.81   6,624,853.21
# Closing Balance    22,038,247.17  24,198,247.17

# %%
combined_loan.to_csv('combined_data_loan.csv')
